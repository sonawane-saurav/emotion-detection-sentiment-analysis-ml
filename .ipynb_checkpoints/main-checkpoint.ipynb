# %%
# !pip install transformers datasets torch
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting transformers
#   Downloading transformers-5.7.0-py3-none-any.whl.metadata (33 kB)
# Collecting datasets
#   Downloading datasets-4.8.5-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: torch in c:\users\vsaur\appdata\roaming\python\python313\site-packages (2.11.0)
# Collecting huggingface-hub<2.0,>=1.5.0 (from transformers)
#   Downloading huggingface_hub-1.12.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: numpy>=1.17 in d:\anaconda\lib\site-packages (from transformers) (2.3.5)
# Requirement already satisfied: packaging>=20.0 in d:\anaconda\lib\site-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in d:\anaconda\lib\site-packages (from transformers) (6.0.3)
# Collecting regex>=2025.10.22 (from transformers)
#   Downloading regex-2026.4.4-cp313-cp313-win_amd64.whl.metadata (41 kB)
# Collecting tokenizers<=0.23.0,>=0.22.0 (from transformers)
#   Downloading tokenizers-0.22.2-cp39-abi3-win_amd64.whl.metadata (7.4 kB)
# Requirement already satisfied: typer in d:\anaconda\lib\site-packages (from transformers) (0.17.4)
# Collecting safetensors>=0.4.3 (from transformers)
#   Downloading safetensors-0.7.0-cp38-abi3-win_amd64.whl.metadata (4.2 kB)
# Requirement already satisfied: tqdm>=4.27 in d:\anaconda\lib\site-packages (from transformers) (4.67.1)
# Requirement already satisfied: filelock>=3.10.0 in d:\anaconda\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in d:\anaconda\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (2025.10.0)
# Collecting hf-xet<2.0.0,>=1.4.3 (from huggingface-hub<2.0,>=1.5.0->transformers)
#   Downloading hf_xet-1.4.3-cp37-abi3-win_amd64.whl.metadata (4.9 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in d:\anaconda\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (0.28.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in d:\anaconda\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (4.15.0)
# Requirement already satisfied: anyio in d:\anaconda\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (4.10.0)
# Requirement already satisfied: certifi in d:\anaconda\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in d:\anaconda\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (1.0.9)
# Requirement already satisfied: idna in d:\anaconda\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (3.11)
# Requirement already satisfied: h11>=0.16 in d:\anaconda\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (0.16.0)
# Requirement already satisfied: pyarrow>=21.0.0 in d:\anaconda\lib\site-packages (from datasets) (21.0.0)
# Requirement already satisfied: dill<0.4.2,>=0.3.0 in d:\anaconda\lib\site-packages (from datasets) (0.4.0)
# Requirement already satisfied: pandas in d:\anaconda\lib\site-packages (from datasets) (2.3.3)
# Requirement already satisfied: requests>=2.32.2 in d:\anaconda\lib\site-packages (from datasets) (2.32.5)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.7.0-cp313-cp313-win_amd64.whl.metadata (13 kB)
# Collecting multiprocess<0.70.20 (from datasets)
#   Downloading multiprocess-0.70.19-py313-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in d:\anaconda\lib\site-packages (from fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (3.13.2)
# Collecting dill<0.4.2,>=0.3.0 (from datasets)
#   Downloading dill-0.4.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: setuptools<82 in d:\anaconda\lib\site-packages (from torch) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in d:\anaconda\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in d:\anaconda\lib\site-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in d:\anaconda\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in d:\anaconda\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in d:\anaconda\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in d:\anaconda\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in d:\anaconda\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in d:\anaconda\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in d:\anaconda\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in d:\anaconda\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.22.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\anaconda\lib\site-packages (from requests>=2.32.2->datasets) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\vsaur\appdata\roaming\python\python313\site-packages (from requests>=2.32.2->datasets) (2.6.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\anaconda\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: colorama in d:\anaconda\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: sniffio>=1.1 in d:\anaconda\lib\site-packages (from anyio->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\anaconda\lib\site-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\anaconda\lib\site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\anaconda\lib\site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\anaconda\lib\site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: six>=1.5 in d:\anaconda\lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Requirement already satisfied: click>=8.0.0 in d:\anaconda\lib\site-packages (from typer->transformers) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in d:\anaconda\lib\site-packages (from typer->transformers) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in d:\anaconda\lib\site-packages (from typer->transformers) (14.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in d:\anaconda\lib\site-packages (from rich>=10.11.0->typer->transformers) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\anaconda\lib\site-packages (from rich>=10.11.0->typer->transformers) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in d:\anaconda\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer->transformers) (0.1.2)
# Downloading transformers-5.7.0-py3-none-any.whl (10.5 MB)
#    ---------------------------------------- 0.0/10.5 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/10.5 MB 4.6 MB/s eta 0:00:03
#    --------- ------------------------------ 2.4/10.5 MB 6.2 MB/s eta 0:00:02
#    --------------- ------------------------ 3.9/10.5 MB 6.5 MB/s eta 0:00:02
#    ---------------------- ----------------- 5.8/10.5 MB 7.2 MB/s eta 0:00:01
#    ----------------------------- ---------- 7.6/10.5 MB 7.4 MB/s eta 0:00:01
#    ------------------------------------- -- 9.7/10.5 MB 7.8 MB/s eta 0:00:01
#    ---------------------------------------- 10.5/10.5 MB 7.5 MB/s  0:00:01
# Downloading huggingface_hub-1.12.0-py3-none-any.whl (646 kB)
#    ---------------------------------------- 0.0/646.8 kB ? eta -:--:--
#    ---------------------------------------- 646.8/646.8 kB 7.4 MB/s  0:00:00
# Downloading hf_xet-1.4.3-cp37-abi3-win_amd64.whl (3.7 MB)
#    ---------------------------------------- 0.0/3.7 MB ? eta -:--:--
#    ------------------- -------------------- 1.8/3.7 MB 9.2 MB/s eta 0:00:01
#    ---------------------------------------- 3.7/3.7 MB 9.5 MB/s  0:00:00
# Downloading tokenizers-0.22.2-cp39-abi3-win_amd64.whl (2.7 MB)
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ------------------------------ --------- 2.1/2.7 MB 11.5 MB/s eta 0:00:01
#    ---------------------------------------- 2.7/2.7 MB 10.2 MB/s  0:00:00
# Downloading datasets-4.8.5-py3-none-any.whl (528 kB)
#    ---------------------------------------- 0.0/529.0 kB ? eta -:--:--
#    ---------------------------------------- 529.0/529.0 kB 6.3 MB/s  0:00:00
# Downloading multiprocess-0.70.19-py313-none-any.whl (156 kB)
# Downloading dill-0.4.1-py3-none-any.whl (120 kB)
# Downloading regex-2026.4.4-cp313-cp313-win_amd64.whl (277 kB)
# Downloading safetensors-0.7.0-cp38-abi3-win_amd64.whl (341 kB)
# Downloading xxhash-3.7.0-cp313-cp313-win_amd64.whl (31 kB)
# Installing collected packages: xxhash, safetensors, regex, hf-xet, dill, multiprocess, huggingface-hub, tokenizers, datasets, transformers
#
#    ---- -----------------------------------  1/10 [safetensors]
#    ---- -----------------------------------  1/10 [safetensors]
#    -------- -------------------------------  2/10 [regex]
#    -------- -------------------------------  2/10 [regex]
#    ------------ ---------------------------  3/10 [hf-xet]
#    ---------------- -----------------------  4/10 [dill]
#    ---------------- -----------------------  4/10 [dill]
#    ---------------- -----------------------  4/10 [dill]
#    ---------------- -----------------------  4/10 [dill]
#    ---------------- -----------------------  4/10 [dill]
#    ---------------- -----------------------  4/10 [dill]
#    ---------------- -----------------------  4/10 [dill]
#    ---------------- -----------------------  4/10 [dill]
#    ---------------- -----------------------  4/10 [dill]
#    ---------------- -----------------------  4/10 [dill]
#    ---------------- -----------------------  4/10 [dill]
#    ---------------- -----------------------  4/10 [dill]
#    -------------------- -------------------  5/10 [multiprocess]
#    -------------------- -------------------  5/10 [multiprocess]
#    -------------------- -------------------  5/10 [multiprocess]
#    -------------------- -------------------  5/10 [multiprocess]
#    -------------------- -------------------  5/10 [multiprocess]
#    -------------------- -------------------  5/10 [multiprocess]
#    -------------------- -------------------  5/10 [multiprocess]
#    -------------------- -------------------  5/10 [multiprocess]
#    -------------------- -------------------  5/10 [multiprocess]
#    -------------------- -------------------  5/10 [multiprocess]
#    -------------------- -------------------  5/10 [multiprocess]
#    ------------------------ ---------------  6/10 [huggingface-hub]
#    ------------------------ ---------------  6/10 [huggingface-hub]
#    ------------------------ ---------------  6/10 [huggingface-hub]
#    ------------------------ ---------------  6/10 [huggingface-hub]
#    ------------------------ ---------------  6/10 [huggingface-hub]
#    ------------------------ ---------------  6/10 [huggingface-hub]
#    ------------------------ ---------------  6/10 [huggingface-hub]
#    ------------------------ ---------------  6/10 [huggingface-hub]
#    ------------------------ ---------------  6/10 [huggingface-hub]
#    ------------------------ ---------------  6/10 [huggingface-hub]
#    ------------------------ ---------------  6/10 [huggingface-hub]
#    ------------------------ ---------------  6/10 [huggingface-hub]
#    ------------------------ ---------------  6/10 [huggingface-hub]
#    ------------------------ ---------------  6/10 [huggingface-hub]
#    ------------------------ ---------------  6/10 [huggingface-hub]
#    ------------------------ ---------------  6/10 [huggingface-hub]
#    ------------------------ ---------------  6/10 [huggingface-hub]
#    ------------------------ ---------------  6/10 [huggingface-hub]
#    ------------------------ ---------------  6/10 [huggingface-hub]
#    ------------------------ ---------------  6/10 [huggingface-hub]
#    ------------------------ ---------------  6/10 [huggingface-hub]
#    ------------------------ ---------------  6/10 [huggingface-hub]
#    ------------------------ ---------------  6/10 [huggingface-hub]
#    ------------------------ ---------------  6/10 [huggingface-hub]
#    ------------------------ ---------------  6/10 [huggingface-hub]
#    ------------------------ ---------------  6/10 [huggingface-hub]
#    ------------------------ ---------------  6/10 [huggingface-hub]
#    ------------------------ ---------------  6/10 [huggingface-hub]
#    ------------------------ ---------------  6/10 [huggingface-hub]
#    ------------------------ ---------------  6/10 [huggingface-hub]
#    ------------------------ ---------------  6/10 [huggingface-hub]
#    ------------------------ ---------------  6/10 [huggingface-hub]
#    ------------------------ ---------------  6/10 [huggingface-hub]
#    ------------------------ ---------------  6/10 [huggingface-hub]
#    ------------------------ ---------------  6/10 [huggingface-hub]
#    ------------------------ ---------------  6/10 [huggingface-hub]
#    ------------------------ ---------------  6/10 [huggingface-hub]
#    ------------------------ ---------------  6/10 [huggingface-hub]
#    ------------------------ ---------------  6/10 [huggingface-hub]
#    ------------------------ ---------------  6/10 [huggingface-hub]
#    ------------------------ ---------------  6/10 [huggingface-hub]
#    ------------------------ ---------------  6/10 [huggingface-hub]
#    ------------------------ ---------------  6/10 [huggingface-hub]
#    ------------------------ ---------------  6/10 [huggingface-hub]
#    ------------------------ ---------------  6/10 [huggingface-hub]
#    ------------------------ ---------------  6/10 [huggingface-hub]
#    ------------------------ ---------------  6/10 [huggingface-hub]
#    ------------------------ ---------------  6/10 [huggingface-hub]
#    ------------------------ ---------------  6/10 [huggingface-hub]
#    ---------------------------- -----------  7/10 [tokenizers]
#    ---------------------------- -----------  7/10 [tokenizers]
#    ---------------------------- -----------  7/10 [tokenizers]
#    ---------------------------- -----------  7/10 [tokenizers]
#    -------------------------------- -------  8/10 [datasets]
#    -------------------------------- -------  8/10 [datasets]
#    -------------------------------- -------  8/10 [datasets]
#    -------------------------------- -------  8/10 [datasets]
#    -------------------------------- -------  8/10 [datasets]
#    -------------------------------- -------  8/10 [datasets]
#    -------------------------------- -------  8/10 [datasets]
#    -------------------------------- -------  8/10 [datasets]
#    -------------------------------- -------  8/10 [datasets]
#    -------------------------------- -------  8/10 [datasets]
#    -------------------------------- -------  8/10 [datasets]
#    -------------------------------- -------  8/10 [datasets]
#    -------------------------------- -------  8/10 [datasets]
#    -------------------------------- -------  8/10 [datasets]
#    -------------------------------- -------  8/10 [datasets]
#    -------------------------------- -------  8/10 [datasets]
#    -------------------------------- -------  8/10 [datasets]
#    -------------------------------- -------  8/10 [datasets]
#    -------------------------------- -------  8/10 [datasets]
#    -------------------------------- -------  8/10 [datasets]
#    -------------------------------- -------  8/10 [datasets]
#    -------------------------------- -------  8/10 [datasets]
#    -------------------------------- -------  8/10 [datasets]
#    -------------------------------- -------  8/10 [datasets]
#    -------------------------------- -------  8/10 [datasets]
#    -------------------------------- -------  8/10 [datasets]
#    -------------------------------- -------  8/10 [datasets]
#    -------------------------------- -------  8/10 [datasets]
#    -------------------------------- -------  8/10 [datasets]
#    -------------------------------- -------  8/10 [datasets]
#    -------------------------------- -------  8/10 [datasets]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ------------------------------------ ---  9/10 [transformers]
#    ---------------------------------------- 10/10 [transformers]
#
# Successfully installed datasets-4.8.5 dill-0.4.1 hf-xet-1.4.3 huggingface-hub-1.12.0 multiprocess-0.70.19 regex-2026.4.4 safetensors-0.7.0 tokenizers-0.22.2 transformers-5.7.0 xxhash-3.7.0
#   WARNING: The scripts hf.exe, huggingface-cli.exe and tiny-agents.exe are installed in 'C:\Users\vsaur\AppData\Roaming\Python\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script datasets-cli.exe is installed in 'C:\Users\vsaur\AppData\Roaming\Python\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script transformers.exe is installed in 'C:\Users\vsaur\AppData\Roaming\Python\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
# !pip install -U accelerate
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting accelerate
#   Downloading accelerate-1.13.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.17 in d:\anaconda\lib\site-packages (from accelerate) (2.3.5)
# Requirement already satisfied: packaging>=20.0 in d:\anaconda\lib\site-packages (from accelerate) (25.0)
# Requirement already satisfied: psutil in d:\anaconda\lib\site-packages (from accelerate) (7.0.0)
# Requirement already satisfied: pyyaml in d:\anaconda\lib\site-packages (from accelerate) (6.0.3)
# Requirement already satisfied: torch>=2.0.0 in c:\users\vsaur\appdata\roaming\python\python313\site-packages (from accelerate) (2.11.0)
# Requirement already satisfied: huggingface_hub>=0.21.0 in c:\users\vsaur\appdata\roaming\python\python313\site-packages (from accelerate) (1.12.0)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\vsaur\appdata\roaming\python\python313\site-packages (from accelerate) (0.7.0)
# Requirement already satisfied: filelock>=3.10.0 in d:\anaconda\lib\site-packages (from huggingface_hub>=0.21.0->accelerate) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in d:\anaconda\lib\site-packages (from huggingface_hub>=0.21.0->accelerate) (2025.10.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in c:\users\vsaur\appdata\roaming\python\python313\site-packages (from huggingface_hub>=0.21.0->accelerate) (1.4.3)
# Requirement already satisfied: httpx<1,>=0.23.0 in d:\anaconda\lib\site-packages (from huggingface_hub>=0.21.0->accelerate) (0.28.1)
# Requirement already satisfied: tqdm>=4.42.1 in d:\anaconda\lib\site-packages (from huggingface_hub>=0.21.0->accelerate) (4.67.1)
# Requirement already satisfied: typer in d:\anaconda\lib\site-packages (from huggingface_hub>=0.21.0->accelerate) (0.17.4)
# Requirement already satisfied: typing-extensions>=4.1.0 in d:\anaconda\lib\site-packages (from huggingface_hub>=0.21.0->accelerate) (4.15.0)
# Requirement already satisfied: anyio in d:\anaconda\lib\site-packages (from httpx<1,>=0.23.0->huggingface_hub>=0.21.0->accelerate) (4.10.0)
# Requirement already satisfied: certifi in d:\anaconda\lib\site-packages (from httpx<1,>=0.23.0->huggingface_hub>=0.21.0->accelerate) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in d:\anaconda\lib\site-packages (from httpx<1,>=0.23.0->huggingface_hub>=0.21.0->accelerate) (1.0.9)
# Requirement already satisfied: idna in d:\anaconda\lib\site-packages (from httpx<1,>=0.23.0->huggingface_hub>=0.21.0->accelerate) (3.11)
# Requirement already satisfied: h11>=0.16 in d:\anaconda\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub>=0.21.0->accelerate) (0.16.0)
# Requirement already satisfied: setuptools<82 in d:\anaconda\lib\site-packages (from torch>=2.0.0->accelerate) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in d:\anaconda\lib\site-packages (from torch>=2.0.0->accelerate) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in d:\anaconda\lib\site-packages (from torch>=2.0.0->accelerate) (3.5)
# Requirement already satisfied: jinja2 in d:\anaconda\lib\site-packages (from torch>=2.0.0->accelerate) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\anaconda\lib\site-packages (from sympy>=1.13.3->torch>=2.0.0->accelerate) (1.3.0)
# Requirement already satisfied: colorama in d:\anaconda\lib\site-packages (from tqdm>=4.42.1->huggingface_hub>=0.21.0->accelerate) (0.4.6)
# Requirement already satisfied: sniffio>=1.1 in d:\anaconda\lib\site-packages (from anyio->httpx<1,>=0.23.0->huggingface_hub>=0.21.0->accelerate) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\anaconda\lib\site-packages (from jinja2->torch>=2.0.0->accelerate) (3.0.2)
# Requirement already satisfied: click>=8.0.0 in d:\anaconda\lib\site-packages (from typer->huggingface_hub>=0.21.0->accelerate) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in d:\anaconda\lib\site-packages (from typer->huggingface_hub>=0.21.0->accelerate) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in d:\anaconda\lib\site-packages (from typer->huggingface_hub>=0.21.0->accelerate) (14.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in d:\anaconda\lib\site-packages (from rich>=10.11.0->typer->huggingface_hub>=0.21.0->accelerate) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\anaconda\lib\site-packages (from rich>=10.11.0->typer->huggingface_hub>=0.21.0->accelerate) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in d:\anaconda\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer->huggingface_hub>=0.21.0->accelerate) (0.1.2)
# Downloading accelerate-1.13.0-py3-none-any.whl (383 kB)
# Installing collected packages: accelerate
# Successfully installed accelerate-1.13.0
#   WARNING: The scripts accelerate-config.exe, accelerate-estimate-memory.exe, accelerate-launch.exe, accelerate-merge-weights.exe and accelerate.exe are installed in 'C:\Users\vsaur\AppData\Roaming\Python\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
import pandas as pd
import torch
from datasets import Dataset
from transformers import AutoTokenizer, AutoModelForSequenceClassification, Trainer, TrainingArguments

# %%
import pandas as pd

df = pd.read_csv("data/train.tsv", sep="\t", header=None)
df.columns = ["text", "label", "id"]

df.head()
# Out:
#                                                 text label       id
# 0  My favourite food is anything I didn't have to...    27  eebbqej
# 1  Now if he does off himself, everyone will thin...    27  ed00q6i
# 2                     WHY THE FUCK IS BAYLESS ISOING     2  eezlygj
# 3                        To make her feel threatened    14  ed7ypvh
# 4                             Dirty Southern Wankers     3  ed0bdzj

# %%
print(df["label"].head(10))
print("Unique labels:", df["label"].nunique())
# Out:
# 0      27
# 1      27
# 2       2
# 3      14
# 4       3
# 5      26
# 6      15
# 7    8,20
# 8       0
# 9      27
# Name: label, dtype: object
# Unique labels: 711

# %%
def clean_label(label):
    # handle multi-label like "8,20"
    if isinstance(label, str) and "," in label:
        label = label.split(",")[0]
    
    return int(label) % 6

df["label"] = df["label"].apply(clean_label)

df["label"].value_counts()
# Out:
# label
# 3    18142
# 0     7583
# 1     5695
# 4     5010
# 2     4325
# 5     2655
# Name: count, dtype: int64

# %%
dataset = Dataset.from_pandas(df)
dataset = dataset.train_test_split(test_size=0.1)

# %%
# Tokenization

tokenizer = AutoTokenizer.from_pretrained("distilbert-base-uncased")

def tokenize(example):
    return tokenizer(example["text"], truncation=True, padding="max_length")

dataset = dataset.map(tokenize, batched=True)
# Out:
# Map:   0%|          | 0/39069 [00:00<?, ? examples/s]
# Map:   0%|          | 0/4341 [00:00<?, ? examples/s]

# %%
model = AutoModelForSequenceClassification.from_pretrained(
    "distilbert-base-uncased",
    num_labels=6
)
# Out:
# Loading weights:   0%|          | 0/100 [00:00<?, ?it/s]
# [transformers] DistilBertForSequenceClassification LOAD REPORT from: distilbert-base-uncased
# Key                     | Status     |
# ------------------------+------------+-
# vocab_projector.bias    | UNEXPECTED |
# vocab_layer_norm.weight | UNEXPECTED |
# vocab_transform.bias    | UNEXPECTED |
# vocab_transform.weight  | UNEXPECTED |
# vocab_layer_norm.bias   | UNEXPECTED |
# pre_classifier.bias     | MISSING    |
# classifier.bias         | MISSING    |
# pre_classifier.weight   | MISSING    |
# classifier.weight       | MISSING    |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING:	those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.

# %%
training_args = TrainingArguments(
    output_dir="./results",
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    num_train_epochs=2,
    eval_strategy="epoch",
    save_strategy="epoch",
    logging_dir="./logs"
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=dataset["train"],
    eval_dataset=dataset["test"]
)

trainer.train()
# Out:
# [transformers] `logging_dir` is deprecated and will be removed in v5.2. Please set `TENSORBOARD_LOGGING_DIR` instead.
# C:\Users\vsaur\AppData\Roaming\Python\Python313\site-packages\torch\utils\data\dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
#     <div>
#
#       <progress value='4' max='4884' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [   4/4884 04:23 < 178:47:00, 0.01 it/s, Epoch 0.00/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
